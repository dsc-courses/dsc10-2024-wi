# %%
import os

def write_markdown_file(line):
    # Split the line by tab to get individual fields
    fields = line.strip().split('\t')
    
    # Extract information from fields
    timestamp, full_name, pronouns, _, description, hometown, askabout, food = fields
    first_name, last_name = full_name.split()
    
    # Format the markdown content
    # Need to manually change the food emoji later
    content = f"""---
name: {full_name}
role: Tutor
pronouns: {pronouns}
email: 
photo: ../assets/staff-images/wi24/{last_name.lower()}-{first_name.lower()}.jpg
description: {description}
hometown: {hometown}
askabout: {askabout}
foodemoji: 🍛 
food: {food}
---"""
    
    path = "../_staffers/"

    # Define the file name
    file_name = f"{path}{last_name.lower()}-{first_name.lower()}.md"
    
    # Write the content to the file
    with open(file_name, 'w') as f:
        f.write(content)
    
    print(f"{file_name} has been written successfully!")

# %%
# Copy-paste the eight relevant columns from the staff onboarding form responses
all_lines = """1/3/2024 11:31:00	Aaron Rasin	he/him	https://drive.google.com/file/d/1frQe4Z09_BbIGL6bifbXLgvYesR0VBf6/view?usp=sharing	4th year, Linguistics, Seventh	Newton, MA	Linguistics at UCSD, the La Jolla Symphony	Tacos El Gordo, Puesto, Main Chick
1/3/2024 12:44:11	Doris Gao	she/her	https://photos.app.goo.gl/hhiRYchdjPUfAsg86	4th year, Data Science and Math-Econ, Marshall	San Francisco, CA	My internship at Scripps Institution of Oceanography, boba	Sushi Ota, Wa Dinning Okan, Blue Water
1/3/2024 16:19:19	Ashley Ho	she/her	https://drive.google.com/file/d/1axBMlAyfSICSAP0nZZtjnPi6-aEkZ0in/view?usp=sharing	4th year, Probability & Statistics, Marshall	Irvine, CA	Cooking, movies/TV shows, corgis	Tasty Noodle House, Pho La Jolla, Monello
1/3/2024 17:59:52	Ester Tsai	she/her	https://drive.google.com/file/d/1r-v8jm-fpMXt5pvsGqIBjaYbhquoEEYG/view?usp=sharing	4th year, Data Science, Math Minor, Sixth	Pleasanton, CA	My internship at Amazon or Thermo Fisher Scientific, tennis, Christian fellowship	Cava, Tasty Noodle House, 85°C Bakery
1/3/2024 18:51:05	Ciro Zhang	he/him	https://drive.google.com/file/d/1sw0lE791jZmE3fRRtuHlT9a8ibpZ2pWi/view?usp=sharing	2nd year, Data Science, Computer Engineering, ERC	Richmond, BC, Canada	Badminton, snowboarding, chess	Shake Shack, Qin West Noodle and Chipotle
1/3/2024 20:24:50	Oren Ciolli	he/him	https://drive.google.com/file/d/10KWQ5rUMgfQT_L-Af4452BST5o97dflb/view?usp=sharing	4th year, Data Science and Math-Econ, Revelle	San Jose, CA	Basketball, music, cooking	Raki Raki, Turmeric Thai Kitchen, Tasty Noodle House
1/3/2024 21:17:46	Keenan Serrao	he/him	https://drive.google.com/file/d/1EHVeeaCvbVx4OpgFzM_kWEcj64P11Vh6/view?usp=sharing	2nd year, Data Science, Sixth	Dallas, TX	Gym, music, food, cars	Seasurf, RakiRaki Ramen, Din Tai Fung
lines = all_lines.split("\n")
for line in lines:
    write_markdown_file(line)
# Out:
# ../_staffers/rasin-aaron.md has been written successfully!
# ../_staffers/gao-doris.md has been written successfully!
# ../_staffers/ho-ashley.md has been written successfully!
# ../_staffers/tsai-ester.md has been written successfully!
# ../_staffers/zhang-ciro.md has been written successfully!
# ../_staffers/ciolli-oren.md has been written successfully!
# ../_staffers/serrao-keenan.md has been written successfully!
# ../_staffers/tkachenko-sofia.md has been written successfully!
# ../_staffers/prabhu-pallavi.md has been written successfully!
# ../_staffers/seyoum-abel.md has been written successfully!
# ../_staffers/ho-chiachan.md has been written successfully!
# ../_staffers/xu-guoxuan.md has been written successfully!
# ../_staffers/roberg-gina.md has been written successfully!
# ../_staffers/hoang-raine.md has been written successfully!
# ../_staffers/determan-jack.md has been written successfully!
# ../_staffers/wu-ylesia.md has been written successfully!
# ...

# %%
import os
import re
import csv
import requests
from PIL import Image
from io import BytesIO

def download_and_save_images(csv_content, directory):
    # Create directory if it doesn't exist
    if not os.path.exists(directory):
        os.makedirs(directory)
    
    # Parse the CSV content line by line
    reader = csv.reader(csv_content.splitlines())
    next(reader)  # Skip the header row
    
    for row in reader:
        print(row)
        timestamp, full_name, pronouns, link = row[0].split("\t")
        first_name, last_name = full_name.split()
        
        # Format the file name
        file_name = f"{last_name.lower()}-{first_name.lower()}.jpg"
        file_path = os.path.join(directory, file_name)
        
        match = re.search(r'/d/([^/]+)/', link)
        if match:
            file_id = match.group(1)
            download_link = f"https://drive.google.com/uc?export=download&id={file_id}"
        else:
            print(f"Failed to extract file ID from link for {full_name}. Skipping.")
            continue
        
        try:
            # Download the image using the modified download link
            response = requests.get(download_link)
            response.raise_for_status()
            
            # Open the image and convert it to JPEG if necessary
            img = Image.open(BytesIO(response.content))
            if img.format != 'JPEG':
                img = img.convert('RGB')
            
            # Save the image to the specified directory
            img.save(file_path, 'JPEG')
            print(f"Image for {full_name} has been saved successfully to {file_path}")
        
        except Exception as e:
            print(f"Failed to download and save image for {full_name}. Error: {e}")

# The CSV content
csv_content = """9/18/2023 15:48:03	Norah Kerendian	she/her	https://drive.google.com/file/d/16mvLT-ueRnHhdvPDM0_im_gEOEj2bMsj/view?usp=sharing
9/23/2023 10:38:03	Arjun Malleswaran	he/him	https://drive.google.com/file/d/1NNfZqOmAeINVCmB2TlwPFepGotQSbw57/view?usp=sharing"""

# The directory where the images should be saved
directory = "../assets/staff-images/wi24"

# Call the function with the CSV content and the directory
download_and_save_images(csv_content, directory)
# Out:
# ['9/23/2023 10:38:03\tArjun Malleswaran\the/him\thttps://drive.google.com/file/d/1NNfZqOmAeINVCmB2TlwPFepGotQSbw57/view?usp=sharing']
# Image for Arjun Malleswaran has been saved successfully to ../assets/staff-images/wi24\malleswaran-arjun.jpg
